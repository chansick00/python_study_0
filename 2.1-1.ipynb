# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# %%
import matplotlib as mpl
# 폰트 설정
mpl.rc('font', family='NanumGothic')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %%
import sklearn as sk

# %%
pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\82107\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: numpy in c:\users\82107\anaconda3\lib\site-packages (from missingno) (1.21.2)
# Requirement already satisfied: seaborn in c:\users\82107\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: scipy in c:\users\82107\anaconda3\lib\site-packages (from missingno) (1.7.3)
# Requirement already satisfied: matplotlib in c:\users\82107\anaconda3\lib\site-packages (from missingno) (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\82107\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\82107\anaconda3\lib\site-packages (from matplotlib->missingno) (4.28.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\82107\anaconda3\lib\site-packages (from matplotlib->missingno) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\82107\anaconda3\lib\site-packages (from matplotlib->missingno) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\82107\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\82107\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\82107\anaconda3\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\82107\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\82107\anaconda3\lib\site-packages (from seaborn->missingno) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\82107\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2021.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno

# %%
titanic = sns.load_dataset('titanic')
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
msno.matrix(titanic)
plt.show()

# %%
sns.countplot(titanic.embark_town)
plt.title('embark_town 데이터의 분포')
plt.show()

# %%
from sklearn.impute import SimpleImputer

imputer_embark_town = SimpleImputer(strategy="most_frequent")
titanic["embark_town"] = imputer_embark_town.fit_transform(titanic[["embark_town"]])
titanic["embarked"] = imputer_embark_town.fit_transform(titanic[["embarked"]])

msno.matrix(titanic)
plt.show()

# %%
sns.kdeplot(titanic.age)
plt.title("age 데이터의 분포")
plt.show()

# %%
# 데이터가 절반 이상이 없는 열을 삭제
titanic = titanic.dropna(thresh=int(len(titanic) * 0.5), axis=1)
msno.matrix(titanic)
plt.show()

# %%
imputer_age = SimpleImputer(strategy="median")
titanic["age"] = imputer_embark_town.fit_transform(titanic[["age"]])

msno.matrix(titanic)
plt.show()

# %% [markdown]
# ## patsy 패키지

# %%
from patsy import demo_data

df = pd.DataFrame(demo_data('x1','x2', 'x3', 'x4', 'x5'))
df
# Out:
#          x1        x2        x3        x4        x5
# 0  1.764052 -0.977278  0.144044  0.333674 -2.552990
# 1  0.400157  0.950088  1.454274  1.494079  0.653619
# 2  0.978738 -0.151357  0.761038 -0.205158  0.864436
# 3  2.240893 -0.103219  0.121675  0.313068 -0.742165
# 4  1.867558  0.410599  0.443863 -0.854096  2.269755

# %% [markdown]
# > data_transformed = dmatrix(formula, data)

# %%
from patsy import dmatrix

dmatrix("x1 + 0", data = df)
# Out:
# DesignMatrix with shape (5, 1)
#        x1
#   1.76405
#   0.40016
#   0.97874
#   2.24089
#   1.86756
#   Terms:
#     'x1' (column 0)

# %%
dmatrix("x1 + x2 + x3 + 0", data=df)
# Out:
# DesignMatrix with shape (5, 3)
#        x1        x2       x3
#   1.76405  -0.97728  0.14404
#   0.40016   0.95009  1.45427
#   0.97874  -0.15136  0.76104
#   2.24089  -0.10322  0.12168
#   1.86756   0.41060  0.44386
#   Terms:
#     'x1' (column 0)
#     'x2' (column 1)
#     'x3' (column 2)

# %%
dmatrix('x1 + x2 + x3', data = df)
# Out:
# DesignMatrix with shape (5, 4)
#   Intercept       x1        x2       x3
#           1  1.76405  -0.97728  0.14404
#           1  0.40016   0.95009  1.45427
#           1  0.97874  -0.15136  0.76104
#           1  2.24089  -0.10322  0.12168
#           1  1.86756   0.41060  0.44386
#   Terms:
#     'Intercept' (column 0)
#     'x1' (column 1)
#     'x2' (column 2)
#     'x3' (column 3)

# %%
dmatrix('x1 + x2 +x3 -1', data = df)
# Out:
# DesignMatrix with shape (5, 3)
#        x1        x2       x3
#   1.76405  -0.97728  0.14404
#   0.40016   0.95009  1.45427
#   0.97874  -0.15136  0.76104
#   2.24089  -0.10322  0.12168
#   1.86756   0.41060  0.44386
#   Terms:
#     'x1' (column 0)
#     'x2' (column 1)
#     'x3' (column 2)

# %%
dmatrix('x1 + np.log(np.abs(x2))', df)
# Out:
# DesignMatrix with shape (5, 3)
#   Intercept       x1  np.log(np.abs(x2))
#           1  1.76405            -0.02298
#           1  0.40016            -0.05120
#           1  0.97874            -1.88811
#           1  2.24089            -2.27090
#           1  1.86756            -0.89014
#   Terms:
#     'Intercept' (column 0)
#     'x1' (column 1)
#     'np.log(np.abs(x2))' (column 2)

# %%
def ten_times(x):
    return 10*x

dmatrix('ten_times(x1)', df)
# Out:
# DesignMatrix with shape (5, 2)
#   Intercept  ten_times(x1)
#           1       17.64052
#           1        4.00157
#           1        9.78738
#           1       22.40893
#           1       18.67558
#   Terms:
#     'Intercept' (column 0)
#     'ten_times(x1)' (column 1)

# %%
dmatrix('x1 + x2 + x1:x2 +0 ', df)
# Out:
# DesignMatrix with shape (5, 3)
#        x1        x2     x1:x2
#   1.76405  -0.97728  -1.72397
#   0.40016   0.95009   0.38018
#   0.97874  -0.15136  -0.14814
#   2.24089  -0.10322  -0.23130
#   1.86756   0.41060   0.76682
#   Terms:
#     'x1' (column 0)
#     'x2' (column 1)
#     'x1:x2' (column 2)

# %% [markdown]
# 위 아래 수식이 같음

# %%
dmatrix('x1 * x2 +0', df)
# Out:
# DesignMatrix with shape (5, 3)
#        x1        x2     x1:x2
#   1.76405  -0.97728  -1.72397
#   0.40016   0.95009   0.38018
#   0.97874  -0.15136  -0.14814
#   2.24089  -0.10322  -0.23130
#   1.86756   0.41060   0.76682
#   Terms:
#     'x1' (column 0)
#     'x2' (column 1)
#     'x1:x2' (column 2)

# %% [markdown]
# 상호작용을 제외한 경우에는 I( )라는 연산자 사용

# %%
dmatrix('x1 + x2 + I(x1 + x2 )+ 0', df)
# Out:
# DesignMatrix with shape (5, 3)
#        x1        x2  I(x1 + x2)
#   1.76405  -0.97728     0.78677
#   0.40016   0.95009     1.35025
#   0.97874  -0.15136     0.82738
#   2.24089  -0.10322     2.13767
#   1.86756   0.41060     2.27816
#   Terms:
#     'x1' (column 0)
#     'x2' (column 1)
#     'I(x1 + x2)' (column 2)

# %%
# x1데이터의 평균

dm = dmatrix('center(x1) + 0', df)
dm
# Out:
# DesignMatrix with shape (5, 1)
#   center(x1)
#      0.31377
#     -1.05012
#     -0.47154
#      0.79061
#      0.41728
#   Terms:
#     'center(x1)' (column 0)

# %%
# x1의 데이터에서 x1의 평균을 빼기 

df.x1 - np.mean(df.x1)
# Out:
# 0    0.313773
# 1   -1.050123
# 2   -0.471542
# 3    0.790613
# 4    0.417278
# Name: x1, dtype: float64

# %%
# design_info라는 속성 내부에 저장

dm.design_info.factor_infos
# Out:
# {EvalFactor('center(x1)'): FactorInfo(factor=EvalFactor('center(x1)'),
#             type='numerical',
#             state=<factor state>,
#             num_columns=1)}

# %% [markdown]
# ## sklearn.preprocessing 패키지

# %%
X = np.arange(7).reshape(-1,1)
X
# Out:
# array([[0],
#        [1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6]])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit_transform(X)
# Out:
# array([[-1.5],
#        [-1. ],
#        [-0.5],
#        [ 0. ],
#        [ 0.5],
#        [ 1. ],
#        [ 1.5]])

# %%
X2 = np.vstack([X, [[1000]]])
X2
# Out:
# array([[   0],
#        [   1],
#        [   2],
#        [   3],
#        [   4],
#        [   5],
#        [   6],
#        [1000]])

# %%
scaler.fit_transform(X2)
# Out:
# array([[-0.38705669],
#        [-0.38402392],
#        [-0.38099115],
#        [-0.37795839],
#        [-0.37492562],
#        [-0.37189286],
#        [-0.36886009],
#        [ 2.64570872]])

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
scaler.fit_transform(X2)
# Out:
# array([[-1.00000000e+00],
#        [-7.14285714e-01],
#        [-4.28571429e-01],
#        [-1.42857143e-01],
#        [ 1.42857143e-01],
#        [ 4.28571429e-01],
#        [ 7.14285714e-01],
#        [ 2.84714286e+02]])

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
poly.fit_transform(X)
# Out:
# array([[ 1.,  0.,  0.],
#        [ 1.,  1.,  1.],
#        [ 1.,  2.,  4.],
#        [ 1.,  3.,  9.],
#        [ 1.,  4., 16.],
#        [ 1.,  5., 25.],
#        [ 1.,  6., 36.]])

# %%
X = 90 * np.arange(9).reshape(-1, 1) 
X
# Out:
# array([[  0],
#        [ 90],
#        [180],
#        [270],
#        [360],
#        [450],
#        [540],
#        [630],
#        [720]])

# %%
from sklearn.preprocessing import FunctionTransformer

def degree2sincos(X):
    x0 = np.sin(X * np.pi / 180)
    x1 = np.cos(X * np.pi / 180)
    X_new = np.hstack([x0, x1])
    return X_new

X2 = FunctionTransformer(degree2sincos).fit_transform(X)

plt.subplot(211)
plt.plot(X, marker="o")
plt.yticks(X.flatten())
plt.title("각도 표현")
plt.subplot(212)
plt.plot(X2, marker="o")
plt.title("삼각함수 표현")
plt.tight_layout()
plt.show()
