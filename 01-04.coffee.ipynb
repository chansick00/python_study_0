# %% [markdown]
# ## 공공데이터를 이용한 카페 상권분석(2020 Ver.)
#
#
# **들어가며**
#
# - 공공데이터를 통해 대한민국을 이해해봅시다(?).
# - 공공데이터포털(data.go.kr)에 다양한 데이터가 공개되어 있습니다.
# - 그 중에 카페(라는 업종분류)들에 대해서 현황을 조사하려고 합니다.
#
# **명세사항**
# 1. 전국 카페 데이터를 모두 수집해야합니다.
# 2. 지역별 or 브랜드별 점포 현황을 확인합니다.
# 3. 분석 결과를 시각화합니다.
#
#
#
# [데이터] https://www.data.go.kr/data/15012005/fileData.do

# %%
# 라이브러리를 불러옵니다.

import pandas as pd

# %% [markdown]
# ## 1. 데이터 불러오기

# %%
# 다운로드 받은 데이터중 일부를 열어봅니다.
temp = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_강원_202012.csv',sep='|', encoding='utf-8')
temp
# Out:
#           상가업소번호            상호명     지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       17175358           국수나루     NaN         Q       음식       Q01
# 1       25033300      동그라미중고타이어     NaN         D       소매       D23
# 2       17174549  세인트존스호텔Ohcrab     NaN         O       숙박       O01
# 3       17174079        평창라마다호텔     NaN         O       숙박       O01
# 4       17173904    호텔탑스텐스카이라운지     NaN         O       숙박       O01
# ...          ...            ...     ...       ...      ...       ...
# 112756  17217972            그린존     NaN         F    생활서비스       F02
# 112757  17224565            시스템  베스트냉난방         F    생활서비스       F15
# 112758  17221168         건어물문방구     NaN         D       소매       D01
# 112759  17221154          명한건어물     NaN         D       소매       D01
# 112760  17221153         노다지건어물     NaN         D       소매       D01
#
#          상권업종중분류명 상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...  \
# 0              한식    Q01A01  한식/백반/한정식   I56111  ...
# 1       자동차/자동차용품    D23A04      타이어판매   G45211  ...
# 2           호텔/콘도    O01A01      호텔/콘도      NaN  ...
# 3           호텔/콘도    O01A01      호텔/콘도      NaN  ...
# 4           호텔/콘도    O01A01      호텔/콘도      NaN  ...
# ...           ...       ...        ...      ...  ...
# 112756   세탁/가사서비스    F02A05      청소/소독      NaN  ...
# 112757       주택수리    F15A03    배관난방보일러   F42201  ...
# 112758    음/식료품소매    D01A11       건어물상   G47213  ...
# 112759    음/식료품소매    D01A11       건어물상   G47213  ...
# 112760    음/식료품소매    D01A11       건어물상   G47213  ...
#
#                            건물관리번호          건물명                   도로명주소  \
# 0       4215010900101730002015569          NaN         강원도 강릉시 토성로 193
# 1       4215011100110960006010791          NaN         강원도 강릉시 가작로 270
# 2       4215011300100010001017124      세인트존스호텔         강원도 강릉시 창해로 307
# 3       4276038024102450036000001          NaN    강원도 평창군 대관령면 오목길 107
# 4       4215035029100920001000002          NaN  강원도 강릉시 옥계면 헌화로 455-34
# ...                           ...          ...                     ...
# 112756  4213011200113660020010582          NaN    강원도 원주시 북원로2718번길 12
# 112757  4213010500105810001000001  휴먼시아원주개운1단지          강원도 원주시 개운로 30
# 112758  4213010700116500010025033          NaN          강원도 원주시 토지길 49
# 112759  4217012300000020291020508          NaN          강원도 동해시 일출로 85
# 112760  4223012600100410034000002       새천년건어물        강원도 삼척시 새천년도로 92
#
#          구우편번호    신우편번호  동정보  층정보  호정보          경도         위도
# 0       210934  25531.0  NaN  NaN  NaN  128.896783  37.757642
# 1       210110  25488.0    1  NaN  NaN  128.904472  37.770252
# 2       210120  25467.0  NaN  NaN  NaN  128.920908  37.791299
# 3       232954  25342.0  NaN  NaN  NaN  128.717971  37.660051
# 4       210831  25633.0  NaN  NaN  NaN  129.052902  37.654680
# ...        ...      ...  ...  ...  ...         ...        ...
# 112756  220962  26316.0  NaN    1  102  127.948965  37.385817
# 112757  220723  26446.0  108  NaN  304  127.954798  37.338556
# 112758  220965  26490.0  NaN    2  201  127.957448  37.321381
# 112759  240816  25717.0  NaN  NaN  NaN  129.117373  37.552361
# 112760  245140  25925.0  NaN  NaN  NaN  129.191484  37.439538
#
# [112761 rows x 39 columns]

# %%
# data 폴더에 있는 모든 csv 파일을 읽어오기 위해 glob을 사용합니다.
from glob import glob

# csv 목록 불러오기
file_names = glob('data/*.csv')
total = pd.DataFrame()

# 모든 csv 병합하기
for file_name in file_names:
    temp = pd.read_csv(file_name, sep='|', encoding = 'utf-8')
    total = pd.concat([total, temp])
    

# reset index
total.reset_index(inplace=True)
total
# Out:
# C:\Users\82107\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          index    상가업소번호            상호명      지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0            0  17175358           국수나루      NaN         Q       음식       Q01
# 1            1  25033300      동그라미중고타이어      NaN         D       소매       D23
# 2            2  17174549  세인트존스호텔Ohcrab      NaN         O       숙박       O01
# 3            3  17174079        평창라마다호텔      NaN         O       숙박       O01
# 4            4  17173904    호텔탑스텐스카이라운지      NaN         O       숙박       O01
# ...        ...       ...            ...      ...       ...      ...       ...
# 2416247  93094  17215242         해성국제결혼      NaN         F    생활서비스       F17
# 2416248  93095  17221668             CU  청주우암공원점         D       소매       D03
# 2416249  93096  17222225         슬기로운상회      NaN         D       소매       D03
# 2416250  93097  17222106           김씨상회      NaN         D       소매       D03
# 2416251  93098  17207629          삼화씨에스      NaN         F    생활서비스       F02
#
#            상권업종중분류명 상권업종소분류코드   상권업종소분류명  ...                     건물관리번호  \
# 0                한식    Q01A01  한식/백반/한정식  ...  4215010900101730002015569
# 1         자동차/자동차용품    D23A04      타이어판매  ...  4215011100110960006010791
# 2             호텔/콘도    O01A01      호텔/콘도  ...  4215011300100010001017124
# 3             호텔/콘도    O01A01      호텔/콘도  ...  4276038024102450036000001
# 4             호텔/콘도    O01A01      호텔/콘도  ...  4215035029100920001000002
# ...             ...       ...        ...  ...                        ...
# 2416247  예식/의례/관혼상제    F17A05      결혼상담소  ...  4311311100104460002018922
# 2416248       종합소매점    D03A01        편의점  ...  4311111300103410001046095
# 2416249       종합소매점    D03A06       종합소매  ...  4311111600104370000038563
# 2416250       종합소매점    D03A06       종합소매  ...  4311410300108540001000001
# 2416251    세탁/가사서비스    F02A05      청소/소독  ...  4313011600110760000000001
#
#              건물명                      도로명주소     구우편번호    신우편번호  동정보  층정보  호정보  \
# 0            NaN            강원도 강릉시 토성로 193  210934.0  25531.0  NaN  NaN  NaN
# 1            NaN            강원도 강릉시 가작로 270  210110.0  25488.0    1  NaN  NaN
# 2        세인트존스호텔            강원도 강릉시 창해로 307  210120.0  25467.0  NaN  NaN  NaN
# 3            NaN       강원도 평창군 대관령면 오목길 107  232954.0  25342.0  NaN  NaN  NaN
# 4            NaN     강원도 강릉시 옥계면 헌화로 455-34  210831.0  25633.0  NaN  NaN  NaN
# ...          ...                        ...       ...      ...  ...  ...  ...
# 2416247      NaN      충청북도 청주시 서원구 1순환로 785  362747.0  28668.0   상가  NaN  201
# 2416248      NaN    충청북도 청주시 청원구 향군로15번길 27  363814.0  28538.0  NaN    1  NaN
# 2416249  사천동아아파트        충청북도 청주시 청원구 율봉로 31  363710.0  28341.0  104  NaN  203
# 2416250      NaN  충청북도 청주시 청원구 충청대로139번길 39  363818.0  28326.0  NaN    1  102
# 2416251      NaN        충청북도 충주시 칠금중앙1길 4-9  380965.0  27362.0  NaN  NaN  NaN
#
#                  경도         위도
# 0        128.896783  37.757642
# 1        128.904472  37.770252
# 2        128.920908  37.791299
# 3        128.717971  37.660051
# 4        129.052902  37.654680
# ...             ...        ...
# 2416247  127.464755  36.624187
# 2416248  127.486439  36.647056
# 2416249  127.473439  36.664050
# 2416250  127.492232  36.669295
# 2416251  127.920122  36.980037
#
# [2416252 rows x 40 columns]

# %%
# 분석에 필요한 column을 고릅니다. ## 자유롭게 하셔도 상관없습니다.
data = total[['상호명','지점명','상권업종대분류명','상권업종중분류명','시도명','시군구명','행정동명']]
data
# Out:
#                    상호명      지점명 상권업종대분류명    상권업종중분류명   시도명     시군구명       행정동명
# 0                 국수나루      NaN       음식          한식   강원도      강릉시        옥천동
# 1            동그라미중고타이어      NaN       소매   자동차/자동차용품   강원도      강릉시       포남1동
# 2        세인트존스호텔Ohcrab      NaN       숙박       호텔/콘도   강원도      강릉시        초당동
# 3              평창라마다호텔      NaN       숙박       호텔/콘도   강원도      평창군       대관령면
# 4          호텔탑스텐스카이라운지      NaN       숙박       호텔/콘도   강원도      강릉시        옥계면
# ...                ...      ...      ...         ...   ...      ...        ...
# 2416247         해성국제결혼      NaN    생활서비스  예식/의례/관혼상제  충청북도  청주시 서원구  성화.개신.죽림동
# 2416248             CU  청주우암공원점       소매       종합소매점  충청북도  청주시 청원구        우암동
# 2416249         슬기로운상회      NaN       소매       종합소매점  충청북도  청주시 청원구     율량.사천동
# 2416250           김씨상회      NaN       소매       종합소매점  충청북도  청주시 청원구     율량.사천동
# 2416251          삼화씨에스      NaN    생활서비스    세탁/가사서비스  충청북도      충주시     칠금.금릉동
#
# [2416252 rows x 7 columns]

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2416252 entries, 0 to 2416251
# Data columns (total 40 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   index      int64
#  1   상가업소번호     int64
#  2   상호명        object
#  3   지점명        object
#  4   상권업종대분류코드  object
#  5   상권업종대분류명   object
#  6   상권업종중분류코드  object
#  7   상권업종중분류명   object
#  8   상권업종소분류코드  object
#  9   상권업종소분류명   object
#  10  표준산업분류코드   object
#  11  표준산업분류명    object
#  12  시도코드       int64
#  13  시도명        object
#  14  시군구코드      int64
#  15  시군구명       object
#  16  행정동코드      int64
#  17  행정동명       object
#  18  법정동코드      float64
#  19  법정동명       object
#  20  지번코드       int64
#  21  대지구분코드     int64
#  22  대지구분명      object
#  23  지번본번지      int64
#  24  지번부번지      float64
#  25  지번주소       object
#  26  도로명코드      int64
#  27  도로명        object
#  28  건물본번지      int64
#  29  건물부번지      float64
#  30  건물관리번호     object
#  31  건물명        object
#  32  도로명주소      object
#  33  구우편번호      float64
#  34  신우편번호      float64
#  35  동정보        object
#  36  층정보        object
#  37  호정보        object
#  38  경도         float64
#  39  위도         float64
# dtypes: float64(7), int64(10), object(23)
# memory usage: 737.4+ MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2416252 entries, 0 to 2416251
# Data columns (total 7 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   상호명       object
#  1   지점명       object
#  2   상권업종대분류명  object
#  3   상권업종중분류명  object
#  4   시도명       object
#  5   시군구명      object
#  6   행정동명      object
# dtypes: object(7)
# memory usage: 129.0+ MB

# %%
# 메모리 낭비를 막기 위해 필요없는 변수는 제거합니다.
#total 이제 필요없음
del total

# %%
total.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12548/2383920525.py in <module>
# ----> 1 total.head
#
# NameError: name 'total' is not defined

# %% [markdown]
# ## 2. 데이터 구경하기

# %% [markdown]
# #### 전국 커피 전문점

# %%
set(data['상권업종중분류명'])
# Out:
# {'PC/오락/당구/볼링등',
#  '가구소매',
#  '가방/신발/액세서리',
#  '가전제품소매',
#  '가정/주방/인테리어',
#  '개인/가정용품수리',
#  '개인서비스',
#  '건강/미용식품',
#  '경마/경륜/성인오락',
#  '광고/인쇄',
#  '기타교육기관',
#  '기타서비스업',
#  '기타음식업',
#  '기타판매업',
#  '놀이/여가/취미',
#  '닭/오리요리',
#  '대중목욕탕/휴게',
#  '대행업',
#  '도서관/독서실',
#  '모텔/여관/여인숙',
#  '무도/유흥/가무',
#  '물품기기대여',
#  '민박/하숙',
#  '법무세무회계',
#  '별식/퓨전요리',
#  '부동산관련서비스',
#  '부동산임대',
#  '부동산중개',
#  '부페',
#  '분식',
#  '분양',
#  '사무/문구/컴퓨터',
#  '사진',
#  '사진/광학/정밀기기소매',
#  '선물/팬시/기념품',
#  '세탁/가사서비스',
#  '스포츠/운동',
#  '시계/귀금속소매',
#  '실내운동시설',
#  '실외운동시설',
#  '애견/애완/동물',
#  '양식',
#  '연구소',
#  '연극/영화/극장',
#  '예술품/골동품/수석/분재',
#  '예식/의례/관혼상제',
#  '요가/단전/마사지',
#  '운동/경기용품소매',
#  '운송/배달/택배',
#  '운영관리시설',
#  '유스호스텔',
#  '유아교육',
#  '유아용품',
#  '유흥주점',
#  '음/식료품소매',
#  '음식배달서비스',
#  '의복의류',
#  '의약/의료품소매',
#  '이/미용/건강',
#  '인력/고용/용역알선',
#  '일식/수산물',
#  '자동차/이륜차',
#  '자동차/자동차용품',
#  '장례/묘지',
#  '전시/관람',
#  '제과제빵떡케익',
#  '종교용품판매',
#  '종합소매점',
#  '주유소/충전소',
#  '주택수리',
#  '중고품소매/교환',
#  '중식',
#  '책/서적/도서',
#  '철물/난방/건설자재소매',
#  '취미/오락관련소매',
#  '캠프/별장/펜션',
#  '커피점/카페',
#  '특수교육기관',
#  '패스트푸드',
#  '페인트/유리제품소매',
#  '평가/개발/관리',
#  '학교',
#  '학문교육기타',
#  '학원-보습교습입시',
#  '학원-어학',
#  '학원-예능취미체육',
#  '학원-음악미술무용',
#  '학원-자격/국가고시',
#  '학원-창업취업취미',
#  '학원-컴퓨터',
#  '학원기타',
#  '한식',
#  '행사/이벤트',
#  '호텔/콘도',
#  '화장품소매'}

# %%
# 카페만 뽑아냅니다.
df_coffee = data[data['상권업종중분류명'] == '커피점/카페']
# index를 다시 세팅합니다.
df_coffee.index = range(len(df_coffee))

print("전국 커피 전문점 점포 수 : ", len(df_coffee))
df_coffee
# Out:
# 전국 커피 전문점 점포 수 :  113705
#              상호명     지점명 상권업종대분류명 상권업종중분류명   시도명     시군구명  행정동명
# 0       키즈까페아이사랑     NaN       음식   커피점/카페   강원도      강릉시   성덕동
# 1           카페마실     NaN       음식   커피점/카페   강원도      원주시   단계동
# 2             힐링     NaN       음식   커피점/카페   강원도      원주시   단구동
# 3            드롭탑  속초엑스포점       음식   커피점/카페   강원도      속초시   조양동
# 4          SHIMS     NaN       음식   커피점/카페   강원도      원주시   행구동
# ...          ...     ...      ...      ...   ...      ...   ...
# 113700  만화카페골목대장     NaN       음식   커피점/카페  충청북도  청주시 상당구   성안동
# 113701        각인     NaN       음식   커피점/카페  충청북도  청주시 상당구   성안동
# 113702  스터디카페프렌즈     금천점       음식   커피점/카페  충청북도  청주시 상당구   금천동
# 113703      카페뮤즈     NaN       음식   커피점/카페  충청북도  청주시 상당구   금천동
# 113704        카페   S바누아투       음식   커피점/카페  충청북도  청주시 상당구  용암1동
#
# [113705 rows x 7 columns]

# %% [markdown]
# #### 서울내 커피 전문점

# %%
set(data['시도명'])
# Out:
# {'강원도',
#  '경기도',
#  '경상남도',
#  '경상북도',
#  '광주광역시',
#  '대구광역시',
#  '대전광역시',
#  '부산광역시',
#  '서울특별시',
#  '세종특별자치시',
#  '울산광역시',
#  '인천광역시',
#  '전라남도',
#  '전라북도',
#  '제주특별자치도',
#  '충청남도',
#  '충청북도'}

# %%
# 카페 중에 "서울"에 위치하고 있는 점포만 뽑아냅니다.
df_seoul_coffee = data[(data['상권업종중분류명']== '커피점/카페') & (data['시도명'] == '서울특별시')]
df_seoul_coffee.index = range(len(df_seoul_coffee))
print('서울시 내 커피 전문점 점포 수 :', len(df_seoul_coffee))
df_seoul_coffee
# Out:
# 서울시 내 커피 전문점 점포 수 : 22239
#              상호명          지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명   행정동명
# 0            커피빈  코리아대학로대명거리점       음식   커피점/카페  서울특별시   종로구    혜화동
# 1          요거프레소          쌍문점       음식   커피점/카페  서울특별시   도봉구   쌍문2동
# 2       406번째스토브          NaN       음식   커피점/카페  서울특별시   양천구    목1동
# 3          로얄커피숍          NaN       음식   커피점/카페  서울특별시   강동구   성내2동
# 4         빈트리망원점          망원점       음식   커피점/카페  서울특별시   마포구   망원1동
# ...          ...          ...      ...      ...    ...   ...    ...
# 22234  로컬스티치북앤커피          NaN       음식   커피점/카페  서울특별시  영등포구  영등포본동
# 22235       카페시모          NaN       음식   커피점/카페  서울특별시   동작구  노량진2동
# 22236       만랩커피         오금역점       음식   커피점/카페  서울특별시   송파구   가락본동
# 22237      레프트커피          NaN       음식   커피점/카페  서울특별시  동대문구    회기동
# 22238      더쌍화커피          NaN       음식   커피점/카페  서울특별시   노원구   중계4동
#
# [22239 rows x 7 columns]

# %%
set(df_seoul_coffee['상호명'])
# Out:
# {'24시프리카페신림점',
#  '몬트카페&베이커리',
#  '함께그린카페금빛',
#  '이니스프리그린카페',
#  '발루토피비',
#  '더탑스터디룸',
#  '너나들이',
#  '카페아사',
#  'ON&OFF',
#  '꿈더하기카페',
#  '더바글',
#  '골든스튜디오',
#  '블랙티엔',
#  '준커피',
#  '커피1팀',
#  '투썸플레이스파인애비뉴점',
#  '까페까마르도',
#  '커피빈코리아논현동팍스타워',
#  '더카페동작구청점',
#  '에슬로우커피',
#  '그린하우스',
#  '커피5.1',
#  '빽다방',
#  '로하스까페',
#  '호감카페',
#  '허',
#  '까페플라워',
#  'coffee122-6',
#  '에쎈',
#  '왯커피',
#  '에토커피',
#  '에이커스',
#  '앤탑PC방',
#  '카페베키오',
#  '주미',
#  '풍경A',
#  '팔공티빨라쪼',
#  '케익다방',
#  '쥬씨강남구청역점',
#  '서울만남의광장휴게소할리스매장',
#  '교보핫트랙스',
#  '드디어커피',
#  '카페노아',
#  '페르카루스커피',
#  '행복플러스가게',
#  '알틴',
#  '블룸앤구떼반포리체점',
#  '카페하트',
#  '원숭이커피',
#  '영우국민대학교',
#  '커피노마드',
#  '티눈',
#  '그런커피랩',
#  '이타르트',
#  '고디바케이트윈타워',
#  '꽃올림',
#  '이지카페',
#  'Thecoffeehouse비오는가을아침',
#  '벌스',
#  '초콜렛콘츄러스',
#  '이화다방',
#  '요거프레소응암역점',
#  '쓰임',
#  '커피시네마',
#  '숲에서스터디카페',
#  '머더파커',
#  '하와이사자팩토리',
#  '온화',
#  '카페에벤',
#  '우림',
#  '케이아이디코리아',
#  '쥬씨휘경점',
#  '키커피컴퍼니',
#  'EDIYACOFFEESHOP',
#  '마조앤새디',
#  '빈스코리아',
#  '로즈버드',
#  '루트세븐틴',
#  '바리스타마르코YES24',
#  '커피얌얌',
#  '이디야커피신길썬프라자점',
#  '몽키바나나',
#  '투썸플레이스가산대륭18차점',
#  '메종루포',
#  '키노키노',
#  '프리카페',
#  '헤이피',
#  '화유재',
#  '23홈즈',
#  '아미스커피',
#  '제너시스에프앤비스위트빈',
#  '브렛서울',
#  '라조',
#  '경복궁박광일갤러리카페',
#  '블루라팽커피',
#  '엘비엔또커피',
#  '카페팟',
#  '샌드밥',
#  '어반테라스',
#  'COFFEEBAY',
#  '호랑이카레',
#  '더진국',
#  '팥시샘달',
#  '도토루커피오스',
#  '스낵커',
#  '레뮤즈',
#  '에피소드3',
#  '느티마을사회적협동조합',
#  '벨라지오',
#  '씨엔엔카페',
#  '달코롬커피앤디저트',
#  '101커피컨테이너',
#  '묘사서울',
#  '림폴커피',
#  '앨스트릿커피',
#  '카페루나',
#  '내자상회',
#  '요거프레소장안1호점',
#  '이디야커피은행나무사거리점',
#  '일리',
#  '더블유더블유더블유',
#  '자문밖커피문',
#  '카페론다',
#  '비온후',
#  '메모아',
#  '굴림',
#  '맛남다방',
#  '츄잉쥬스양재점',
#  '달리는커피코리아',
#  '가온누리',
#  '카페아비오',
#  '까페이탈리아코리아',
#  '쥬스올러지',
#  '브타이거커피',
#  '엔제리너스삼성백암아트홀점',
#  '카페구름',
#  '라운지독',
#  '커피투마로우',
#  '365차버블티',
#  '카페라쿤',
#  '티블랙',
#  '잇.',
#  '감꽃당',
#  '비',
#  '퍼즈카페',
#  '엘앤제이커피',
#  '비알브에노스페이스',
#  '온도씨',
#  '까페봄',
#  '카페코나퀸즈',
#  '카페900',
#  'LG전자',
#  '마크69',
#  '제이제이커피',
#  '베네디체레',
#  '카페라끌레',
#  '커피식스쥬스식스천호역점',
#  '라벤더나인',
#  '요이5',
#  '에이미스',
#  '쥬씨',
#  '채터박스',
#  '폴바셋롯데본점',
#  '퓨전2',
#  'CAFEDELCIELO',
#  '청아해',
#  'BMMcafe',
#  '엠티엘',
#  'cafe구석',
#  '미카페토코리아',
#  '스타일커피',
#  '코지',
#  '유아히어합정교보문고점',
#  '프쉬케',
#  'TAIMDISH',
#  '스타벅스구로하이엔드점',
#  '키커피코리아',
#  '데이비드쥬스',
#  '온수밀밭',
#  '카페드비반트',
#  '루카스카페&갤러리',
#  '퍼트커피',
#  '에스프레소인뉴욕',
#  '봉제산아래커피집',
#  '카페코보스',
#  'EDIYACOFFEE',
#  'CODE101',
#  '만화카페냐몽',
#  '마므레',
#  '바니',
#  '남현커피',
#  '동림커피숍',
#  '커피빈코리아방배카페골목',
#  '커피zip',
#  '리쉬케시',
#  '현명커피',
#  '시나본이대서울병원점',
#  '쁠랑커피',
#  '소울푸드',
#  '브루잉웰',
#  '원빈',
#  '헬로우커피',
#  '커피소',
#  'JJY카페',
#  '2카페',
#  '비틀주스홍씨내',
#  '디아트카페',
#  '서가배',
#  '밀당',
#  '커피식스쥬스식스장한평점',
#  '알뜰포차케익까페',
#  '하카롱',
#  '휴cafe',
#  '청구다방',
#  '이씨씨스무디킹',
#  '리베르떼COFFEE',
#  '컬쳐트리',
#  '까페렐리',
#  '도노도노제이',
#  '이야기보따리',
#  '엔카페',
#  '롯데시네마김포공항엔제리너스',
#  '풀오브파운드',
#  '오서독스',
#  '달달해',
#  '커피상회',
#  'IROOM',
#  '커피그리기',
#  '행운당',
#  'MANGOIXACADEMY',
#  'ILNOCE',
#  '더브레드블루',
#  '허브디앤씨',
#  '슈어슈어리커피',
#  '보야커피',
#  '어나더쏭',
#  '금호커피숍',
#  '커핀그루나루대학로점',
#  '빽다방천호역로데오점',
#  '필카페',
#  '소스페소',
#  '최콜릿',
#  '멧커피',
#  '해남커피숍',
#  '카페네꼬',
#  'CAFEMERCI',
#  '카페필림밸런스',
#  '에스페라',
#  '서울리버티벨',
#  '아리스타커피강동구청점',
#  '동네카페',
#  '구름비',
#  '다같이카페',
#  '엔제리너스강남역점',
#  '아이엠씨',
#  '카페레즈로스팅하우스',
#  '르플랑의정원',
#  '니피커피',
#  '커피32',
#  '유목',
#  '자바트래커',
#  '카페라부에노',
#  'J&J로스팅샵',
#  '커피를부탁해',
#  '꼬꼬마',
#  '롤링스톤즈',
#  '판다쥬스',
#  '할리스커피강남역점',
#  '스탠딩커피',
#  '로저스타임',
#  'CNN카페세빛섬점',
#  '또봄',
#  '호밀밭의호두꾼합정점',
#  '한스',
#  '꿈커피',
#  '달숲',
#  '더빠니니',
#  '어보이드보이드커피',
#  '더플랩잭',
#  'G카페PC',
#  '빽다방신림역2호점',
#  '하비',
#  '에쉬본',
#  '씨앗카페느티',
#  '브레댄코',
#  '예랑떡카페',
#  '블랙king콩',
#  '송아지커피숍',
#  '미라클스터디카페',
#  '카페옐로우',
#  '마이쮸키친',
#  '카페레알빈',
#  '도그원카페',
#  '두커피',
#  '커피나무노량진3호점',
#  '무드벨벳',
#  '오가다안국점',
#  '마사니',
#  '굿모닝커피숍',
#  '고촌카페',
#  '카페모니에',
#  '까페블랙펄',
#  '싱싱카페',
#  '헤븐거피숍',
#  '빈스투커피',
#  '숨앤쉼커피',
#  '느린내림',
#  '살롱드카이도',
#  '카페리브로',
#  '청자다방',
#  '아이스크림에듀',
#  '삼청동커피',
#  '카이스트서울캠퍼스점카페그랑',
#  '블루샥',
#  '놀자',
#  '청다방',
#  '쥬씨방화역점',
#  '스테이선샤인',
#  '쥬씨가락점',
#  '카페이브닝',
#  '케이에스케이공인중개사사무소카페',
#  '와이즈커피',
#  '어플렌티오브',
#  '스타벅스서울대입구역점',
#  '더라운드커피',
#  '맥카이하우스',
#  '라크라센타커피&컴퍼니',
#  '덤',
#  'mug공대',
#  '카페고고',
#  '키다리커피',
#  '예셰숄',
#  '몬스트룸커피',
#  '카이로스',
#  '카페루엔비',
#  '스탬스',
#  '노블',
#  '라페스타',
#  '디렉터스커피',
#  '본우리집밥카페일마지오서울검찰',
#  '도쿄빙수익선동',
#  '루소커피랩학원',
#  '자연',
#  '앙꼬',
#  '동건스',
#  '스타벅스코엑스사거리점',
#  '커피볶아주는남자CAFE끌림',
#  '태양커피',
#  '스타벅스명동입구점',
#  '오설록티하우스삼청동점',
#  '해리스커피파크',
#  '파스쿠치여의도점아이리스',
#  '모짜르트',
#  '호감',
#  '블랙워터로스터스',
#  '1월의윤슬',
#  'MINIM',
#  '탭플레이홈플러스',
#  '언덕커피',
#  '란스',
#  'CDT커피바',
#  '커피오즈',
#  '커피사이엔스',
#  '루시',
#  'Cofeeniecafe',
#  '선아커피',
#  '일커피앤띵',
#  '디.베티',
#  '공차양재본점',
#  'CAFELULU',
#  '앨리스토리커피',
#  '모뉴먼트커피',
#  '도프커피로스팅랩',
#  '커브드커피',
#  '송파커피',
#  '리사르커피',
#  '밸류어블모멘트',
#  '브렌다플라워',
#  '카페에프티',
#  '피오레버',
#  '카페시율',
#  '카페르마들렝',
#  '씨제이푸드빌콜드스톤크리',
#  'CAFEMUNDO',
#  '밀르몽',
#  '크레프트카페라온',
#  '커피랑파이랑',
#  '소요하',
#  'Cafe연',
#  'JAM',
#  '에이셉커피',
#  '라떼뜨',
#  '라운드렉탱글RoundRectangle',
#  '매머드커피묵동자이점',
#  '티모커피',
#  '고웨스트',
#  '디캡슐',
#  '마틸다엔와이',
#  '길리',
#  '스카이라인',
#  '한강클래스',
#  '오투오카페',
#  '카페모자이크교회',
#  '왕궁다방',
#  '제이스',
#  '아우어다이브',
#  '목동커피',
#  '아마도',
#  '어야가자',
#  '아웃스탠딩커피지향',
#  '카페보니떼마들점',
#  '도피오국립국악원점',
#  '티나가든',
#  '커피빈코리아낙성대역점',
#  '까페코이노스',
#  '스터디카페U',
#  '주스킹위례',
#  '키커피',
#  '히어로',
#  '윈스컴퍼니',
#  'EDIYA카페',
#  '젤리몬스터',
#  '그래버커피',
#  'April',
#  '네로우패스',
#  'Sapper커피',
#  '제이에스커피랩',
#  '로스팅플래닛',
#  '애담커피',
#  '도봉관',
#  '경북궁앞무드리카페',
#  '커피마을',
#  'AvenchusANDCOFFEE',
#  'CAFFESOSPESO',
#  '카페헤바',
#  '와필레',
#  '커피홀릭강정',
#  '뷰클랜드',
#  '언더스테이티드',
#  '폰드커피',
#  '카페모퉁이',
#  '주다르',
#  'LUFTCOFFEE',
#  '아인',
#  '양촌',
#  '도본',
#  '트리커피',
#  '383커피',
#  '블랙커',
#  '레이크커피바',
#  '카페포르자',
#  '센티미터스페이스',
#  '미오라',
#  '브로일링커피',
#  '더투웰브그로우',
#  '라노비아',
#  '바스크',
#  '정다운커피집',
#  '프랑스에다녀온붕어빵강남점',
#  '커피한잔',
#  '로스터김',
#  '데일리오아시스',
#  '빅컵커피',
#  '코레일유통대방카페',
#  '유니유니',
#  '퍼스커피',
#  '커피램프',
#  '토즈비즈니스센터홍대점',
#  '커피넘버세븐',
#  '샘커피숍',
#  '힐링카페지유',
#  '로제타1890',
#  '세르비찌오카페',
#  'P23',
#  '카페진',
#  '탐앤탐스망원점',
#  '코너스톤',
#  '세이세이세이',
#  '가가커피로스터',
#  '카페글렌',
#  '올리브',
#  '카페캠퍼',
#  '돌체라쎄라',
#  '다르다',
#  '초이스빈',
#  '카페아크',
#  '씨걸',
#  'SAATCHIOWN',
#  '위퍼스트스터디카페',
#  '귀빈',
#  '카페453키친',
#  '홍스커피',
#  '복합문화공간까페가화',
#  '청파동커피',
#  'JD카페',
#  '카페보쿠',
#  '바이림',
#  '타카플레이카페',
#  '달콤커피여의도더디자이너스호텔점',
#  '그랑카페',
#  '광커피',
#  'B+',
#  '붐베이직',
#  '이디야커피정릉아리랑점',
#  '호조카페',
#  '할리스커피신림고시촌점',
#  '눈',
#  '반지마을커플링반지만들기카페',
#  '발리커피숍',
#  '공간다반사',
#  '슬로우가든삼청점',
#  '마리아커피',
#  '레이디해더스룸',
#  '커피앰비언스',
#  'chewychewy',
#  '캔캔커피',
#  '일리카페김포공항테라스점',
#  '성곽마루',
#  '빽다방방화사거리점',
#  '카페바리스타케이에피소드2',
#  '열린',
#  '김군COFFEE',
#  'MAFIACOFFEE',
#  '커피베이종암점',
#  '양남',
#  '달보드레',
#  '썸베이크',
#  '카페곤',
#  '빛',
#  '커피LAB',
#  '투앤나인',
#  '요즘우유',
#  '텅플래닛',
#  '애정다방',
#  '카페매화',
#  '아마스빈버블티',
#  '클라시코',
#  '다시사랑받개',
#  '카페차뜨',
#  '까페업',
#  '가정집커피',
#  '더벤티노량진점',
#  '비원스터디카페',
#  '키위랑커피랑',
#  '쁘띠크로아상',
#  '샘',
#  '북카페다독다독多讀茶讀',
#  '에픽플랜',
#  '모리아',
#  '내커피',
#  '놀숲',
#  '이응지읒이응지읒커피',
#  '에스프레사멘테일리보라매점',
#  '카멜롯',
#  '카페38',
#  '아오스요거트',
#  '플라스크까페',
#  '해이빈',
#  '도피오',
#  '슈가플래닛',
#  '소림커피',
#  'YEOGIYA커피',
#  '미디엄스톤',
#  '데스트로커피',
#  '앱카페',
#  'MNDCOFFEE',
#  'YINYA',
#  '대치720S라운지',
#  '라오나카페',
#  '카페포레',
#  '프로맘킨더',
#  '오설록티하우스시그니쳐타워점',
#  '이가커피',
#  '플러피도넛',
#  '야니',
#  '자작나무이야기',
#  '클로리스티앤씨',
#  '쥬빌리',
#  '코미코미',
#  '강아지똥',
#  '엔제리너스커피구로디',
#  '봉명다방',
#  '미소래플러스',
#  '카페씨드니',
#  '사주까페예지몽',
#  '폴리스팬케이크',
#  '커피잔속에테르',
#  '지구정복을꿈꾸는고양이',
#  '티빠',
#  '커피오쩜일',
#  '유후인',
#  '컵앤커피',
#  '라쿤카페꾸꾸네',
#  '합동휴게실',
#  '스타벅스차병원사거리',
#  '스마일꽈배기',
#  '탄젠트',
#  '클래식플라워까페',
#  '삼양푸드다이닝까페믹스엔',
#  '아티굿띵',
#  '풍성호',
#  '다올상점',
#  '유달리아',
#  '진부책방스튜디오',
#  'TALESPINNERCO',
#  '코오피앤미',
#  '은평카페제시카',
#  '카페구디',
#  '슬로스텝IN홍대',
#  '올스톤커피하우스',
#  '제노까페',
#  '아케이드커피',
#  '동네카페고커피',
#  'DUDART',
#  '오름카페',
#  '꼼레떼',
#  '베네피트',
#  '카페연영',
#  '한끼와커피',
#  '별별다방',
#  '까치다방',
#  '펠른',
#  '커피코트용산아스테리움점',
#  '익선주택',
#  '키쏘커피소소원',
#  '커피머그루',
#  '야미다방',
#  '사과나무',
#  '커피에반하다난곡점',
#  '커피빈남부터미널점',
#  '헬무트',
#  '커피&배달',
#  '고마온GOMAON',
#  '커피비에이',
#  '쏘뇨',
#  '밀키올리',
#  '셀렉토커피마곡점',
#  '카페쉐누',
#  '미도반반찬까페',
#  '쉬즈베이글',
#  '아름다운꽃',
#  'cafe라이스',
#  '로즈커피숍',
#  '갓프레소',
#  '커피501',
#  '공룡커피',
#  '쥬씨남성역점',
#  '공감락까페',
#  '카페제이더블유',
#  '로뎀나무',
#  '일야에스프레소',
#  '벌떼카페',
#  '노워리스',
#  '카페민',
#  '어거스티59',
#  '텐퍼센트커피',
#  '카페에서',
#  '공주밤빵프렌치카페성내점',
#  '에떼라이브카페',
#  '이씨엠디천재교육R&D',
#  '목련다방',
#  'FRESHJOY',
#  '슈퍼커피',
#  '메가엠지씨커피천왕',
#  '썸띵어바웃커피',
#  '벨뷰',
#  '카페123길',
#  '난곡제과',
#  '두잉나띵',
#  '투썸커피',
#  '스타벅스커피강남대로신사',
#  '폴바셋상암MBC미디어센터점',
#  '포포리POPORI',
#  '닉',
#  '아방가르드카페',
#  '어이어',
#  '화이트바닐라',
#  '니아벡',
#  '더더다다퀸마마마켓',
#  '다쿠아랑',
#  '디톡스마켓',
#  '커피공방',
#  '벨로샵',
#  '매머드익스프레스논현원앤원점25호',
#  '공차광화문점',
#  '제이드커피',
#  '라티그레커피',
#  '주얼리카페세림',
#  '카페트리',
#  '파인트리커피',
#  '雪夜',
#  '사카',
#  '허니커피남부지원점',
#  '커피빈코리아도곡동지오빌딩점',
#  '정우연',
#  '핏트커피',
#  '두젠틀',
#  '투썸플레이스서초역점',
#  '카페조율소',
#  '하늘에커피',
#  '르노커피',
#  '알레스카',
#  '세루리안앤드팩토리',
#  'CAFEBLESSING',
#  '니어마이비카페',
#  '클라소피',
#  'CAFE.91',
#  '카페아임',
#  '영화에빠진커피',
#  'EDUGUN',
#  '스튜디오잇',
#  '아르디카페',
#  '겸스커피',
#  'MEGACOFFEE메가커피',
#  '카페도로시',
#  '지하실B1',
#  '환다방',
#  'CAFENO37',
#  '카페뮤즈',
#  '이화',
#  '커피니종합운동장역점',
#  '아레나',
#  '카페쏘도베',
#  '맹커피숍',
#  '타임에프터타임',
#  '온니당',
#  '세븐몽키즈',
#  '카페드람브르',
#  '프롬테오커피',
#  '커피향이좋아서',
#  '어반프룻',
#  '커피빈코리아신사점',
#  '슈퍼커피신도림푸르지오점',
#  '카페달썸',
#  '고양이당',
#  '제이네가게',
#  '천년초와전통차',
#  '스타벅스강동역점',
#  '슬로우스텝',
#  '만랩커피가산',
#  '앙코코',
#  '고디바롯데잠실',
#  '긱스타피씨카페',
#  '리필커피',
#  '사주카페가네샤',
#  '리버파크커피숍',
#  '커피엔수다',
#  'ThirdIam',
#  '카페밀크',
#  '쥬씨독산점',
#  '커피온더테이블',
#  '옻칠갤러리카페',
#  '토프레소역삼점',
#  '삼성웰스토리고려대신의학관Coffee&',
#  '커피볶는집와플에숍',
#  '메가엠지씨커피방학도깨비시장',
#  '희숲',
#  '수수커피컴퍼니',
#  '에버그린',
#  'St.1549',
#  '도화아파트먼트',
#  '모노레일에스프레소',
#  '라스커피',
#  '더쌍화커피',
#  '뜰가든',
#  '메누카',
#  'CAFEHERE',
#  '키스',
#  '공차현대백화점신촌점',
#  '빙고180',
#  'AEDA',
#  '라프리앙',
#  '하니앤손스',
#  'Hcafe',
#  '애플파이',
#  '마노핀압구정역점',
#  '마셔봄',
#  '쿠카쿠',
#  '감성스터디카페숭실대입',
#  '지붕',
#  '여의도팩토리까페커피드메소드',
#  '도깨비커피',
#  'COFFEEDATE커피데이트',
#  '프랑켄모노카페FRANKENMONOCAFE',
#  '더칼라',
#  '카페리사',
#  '오뚜기상조회오뚜기센터점',
#  '스케네브라운',
#  '풍뎅이의숲',
#  '마리웨일',
#  '모즈',
#  '벨가카페',
#  '신일다방',
#  '커피니덕성여대점',
#  '누커피기업',
#  'YI쟁이',
#  '탐스커피앤푸드',
#  '더치앤빈신도림점',
#  '띵굴',
#  '카페예지',
#  '아메리카노스',
#  '커피세븐',
#  '럭키스터디까페',
#  '촌카페',
#  'cafe멍',
#  '카페러블리',
#  '카페델리카토',
#  '모던바이츠',
#  '반달커피서울',
#  '시스템',
#  '정성담음',
#  '몽탄이네M&THOUSE엠엔티하우스',
#  '꽃을바치는시간',
#  '투썸플레이스개화산역점',
#  '1인1잔',
#  '앙뿌',
#  '남산커피집',
#  '바리스타마르코영등포경찰서점',
#  '커피에반하다<가든파이브점>',
#  '아마스빈',
#  '떼루와가산',
#  'FineThankyou',
#  '커피난다',
#  'LCAFE',
#  'snack&coffee',
#  'cafePERA',
#  '음성골만두카페',
#  '지소현로스터스커피',
#  '성수빈티지',
#  '밀희',
#  '소적두압구정본가',
#  '사이사',
#  '카페마리오',
#  '엉클롱',
#  '카페방학',
#  '온다',
#  '궁전커피숍',
#  '파라그라프',
#  'e-커피',
#  '현경개발릴리움커피',
#  'CafeQuerenciaC&C',
#  '금성',
#  '서룡씨앤케이코와핀종합운',
#  '제니스까페',
#  '커피아',
#  '콩스커피',
#  '카페스토리',
#  '초원다방',
#  '케이비샵',
#  '굿모닝커피',
#  '유어플래닛',
#  '욤토브',
#  '카페사근',
#  '머피커피해피',
#  '엉클로',
#  '다나인터내셔널',
#  '디오델커피',
#  '카페퍼슨비',
#  '솔다방',
#  '다향전통차',
#  '코코라',
#  '양과자상점',
#  '카페오로미아',
#  '제르보',
#  '까마르도',
#  '라온',
#  '카페릴리',
#  '심리카페COM',
#  '카페마달',
#  '아라코',
#  '커피랏',
#  '경성꽈배기',
#  '다래사우나내매점',
#  '유달리',
#  '오프체인',
#  '바로서점',
#  '꼬리치는강아지',
#  '카페마약',
#  '범표원두',
#  '카페두루',
#  '유후카페',
#  '카페더램프',
#  '디핀커피',
#  '커피웨이즈',
#  '카페르뷰',
#  '카페류',
#  '올리버스윗',
#  '오잉',
#  '카페공감',
#  '놀숲둔촌역점',
#  '산토리니의아침',
#  '반지만들기대학로본점',
#  '택스쳐성수',
#  '연립빵공장',
#  '이루리북스',
#  '엘에스씨푸드중구청티타임',
#  '누아르블랑',
#  '티모시스커피코리아',
#  '기로',
#  '쉼스토리',
#  '커피에반하다구로디지털단지점',
#  '호텔도마',
#  'Dropp',
#  '쑤앤쑤',
#  '마카롱드쌤',
#  '쿠잉',
#  '카페유원',
#  '스태그STAG',
#  '오드리토스트커피',
#  '아메리카노커피',
#  '테일러커피',
#  '나시타까페',
#  '베이커스필드파미에스테이션점',
#  'GS25연대서문',
#  '일리커피데이콤점701704',
#  '마실',
#  '훈스커피랩',
#  '신양커피',
#  '위너커피',
#  '커피프라하',
#  '제비카페',
#  '할리스커피교통회관',
#  '엘모히또',
#  '북카페',
#  '커피런',
#  '카페본디',
#  '원효로',
#  '나와나타샤와흰당나귀',
#  '커피사피엔스가산',
#  '틴',
#  '쏘나이스커피',
#  '카페있떼',
#  'Quinto',
#  '소소정',
#  '타르퀸',
#  '블랑드티',
#  '디에고젤라또',
#  '아케랩',
#  '더트리',
#  'Chally&Coffee',
#  '세종투자개발세종대가든뷰',
#  '커피구름',
#  '커피앤버블',
#  'THEBOTTLEPLACE',
#  '카페까망',
#  'Igoteverything강동구청',
#  'CGV',
#  '세운나',
#  '커피이즈',
#  '체리블로썸',
#  '해리피아',
#  '브라운즈',
#  'TODAYCAFE',
#  '플리즈커피',
#  '소망풍경',
#  '가루가루',
#  '공감',
#  '수애뇨339',
#  '요요도산대로점',
#  '헤르아',
#  '베러커피',
#  '프레코티',
#  '할리스도심공항점2',
#  'COFFEEBYBOM',
#  'COFFEE&TEE',
#  '스탠다드브루잉',
#  '카페드림뷰',
#  '갤러리아트다림',
#  '엔646',
#  '제네랄드링크샵',
#  '카페로이스',
#  'Clucy',
#  '커피마루',
#  '빌리엔젤',
#  '심풀',
#  '다락방고양이',
#  '카페26',
#  '아쿠아렐',
#  '트롤비즈코리아',
#  '크리스마스자몽목동점',
#  '르솔레일',
#  '브라운필투',
#  '바움아트스페이스',
#  '헤리스헤이스',
#  'CafeG',
#  '카페데이',
#  '알렉스더커피',
#  '인얼스커피',
#  '스타벅스낙성대DT점',
#  '정식카페',
#  '프리모커피',
#  'ONES',
#  '빈트리225',
#  '오늘상점',
#  '카페원더',
#  '성북시니어클럽',
#  '커피N빙수',
#  '호박',
#  '코코브루리',
#  '하울까페',
#  ...}

# %% [markdown]
# #### 전국 스타벅스

# %%
# 이번엔 전국에 있는 스타벅스를 뽑아냅니다.
#.str.contains('스타벅스')  스타벅스를 포함하는 것을 찾아줌

df_starbucks = df_coffee[df_coffee['상호명'].str.contains('스타벅스')]
df_starbucks.index = range(len(df_starbucks))
print('전국 스타벅스 점포 수 :', len(df_starbucks))
df_starbucks
# Out:
# 전국 스타벅스 점포 수 : 1613
#               상호명        지점명 상권업종대분류명 상권업종중분류명   시도명     시군구명    행정동명
# 0            스타벅스        NaN       음식   커피점/카페   강원도      원주시     단계동
# 1      스타벅스강릉안목항점     강릉안목항점       음식   커피점/카페   강원도      강릉시     송정동
# 2            스타벅스  대명델피노리조트점       음식   커피점/카페   강원도      고성군     토성면
# 3     스타벅스춘천후평DT점    춘천후평DT점       음식   커피점/카페   강원도      춘천시    후평3동
# 4            스타벅스      춘천명동점       음식   커피점/카페   강원도      춘천시    약사명동
# ...           ...        ...      ...      ...   ...      ...     ...
# 1608         스타벅스    청주율량DT점       음식   커피점/카페  충청북도  청주시 청원구  율량.사천동
# 1609         스타벅스      충주성서점       음식   커피점/카페  충청북도      충주시  성내.충인동
# 1610         스타벅스        NaN       음식   커피점/카페  충청북도      음성군     원남면
# 1611         스타벅스      충주연수점       음식   커피점/카페  충청북도      충주시     연수동
# 1612         스타벅스        NaN       음식   커피점/카페  충청북도      음성군     맹동면
#
# [1613 rows x 7 columns]

# %% [markdown]
# #### 서울 스타벅스

# %%
# 이번엔 서울에 있는 스타벅스를 뽑아냅니다.
df_seoul_starbucks = df_starbucks[df_starbucks['시도명'] == '서울특별시']
df_seoul_starbucks.index = range(len(df_seoul_starbucks))
print('서울시 내 스타벅스 점포 수 :', len(df_seoul_starbucks))
df_seoul_starbucks.head()
# Out:
# 서울시 내 스타벅스 점포 수 : 509
#            상호명      지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명  행정동명
# 0         스타벅스     대학로점       음식   커피점/카페  서울특별시  종로구   이화동
# 1         스타벅스      한티점       음식   커피점/카페  서울특별시  강남구  대치4동
# 2         스타벅스   동숭로아트점       음식   커피점/카페  서울특별시  종로구   이화동
# 3  스타벅스남부터미널2점  남부터미널2점       음식   커피점/카페  서울특별시  서초구  서초3동
# 4         스타벅스    가로수길점       음식   커피점/카페  서울특별시  강남구   신사동

# %% [markdown]
# #### 전국 이디야

# %%
df_ediya = df_coffee[df_coffee['상호명'].str.contains('이디야')]
df_ediya.index = range(len(df_ediya))
print('전국 이디야 점포 수 :', len(df_ediya))
df_ediya
# Out:
# 전국 이디야 점포 수 : 2238
#         상호명       지점명 상권업종대분류명 상권업종중분류명   시도명     시군구명   행정동명
# 0     이디야커피    원주반곡동점       음식   커피점/카페   강원도      원주시  반곡관설동
# 1     이디야커피     춘천제일점       음식   커피점/카페   강원도      춘천시    강남동
# 2     이디야커피       흥업점       음식   커피점/카페   강원도      원주시    흥업면
# 3     이디야커피     정동진역점       음식   커피점/카페   강원도      강릉시    강동면
# 4     이디야커피    속초동명항점       음식   커피점/카페   강원도      속초시    동명동
# ...     ...       ...      ...      ...   ...      ...    ...
# 2233  이디야커피  오창2산업단지점       음식   커피점/카페  충청북도  청주시 청원구    오창읍
# 2234  이디야커피     가경중앙점       음식   커피점/카페  충청북도  청주시 흥덕구    가경동
# 2235  이디야커피     제천하소점       음식   커피점/카페  충청북도      제천시    용두동
# 2236  이디야커피       NaN       음식   커피점/카페  충청북도      증평군    증평읍
# 2237  이디야커피      충북대점       음식   커피점/카페  충청북도  청주시 서원구    사창동
#
# [2238 rows x 7 columns]

# %% [markdown]
# #### 서울 이디야

# %%
df_seoul_ediya = df_ediya[df_ediya['시도명'] == '서울특별시']
df_seoul_ediya.index = range(len(df_seoul_ediya))
print('서울시 내 이디야 점포 수 :', len(df_seoul_ediya))
df_seoul_ediya.head()
# Out:
# 서울시 내 이디야 점포 수 : 474
#           상호명    지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명
# 0       이디야커피   신길역점       음식   커피점/카페  서울특별시  영등포구  신길1동
# 1       이디야커피   북창동점       음식   커피점/카페  서울특별시    중구   소공동
# 2       이디야커피   라이프점       음식   커피점/카페  서울특별시  영등포구   여의동
# 3       이디야커피    시흥점       음식   커피점/카페  서울특별시   금천구  시흥2동
# 4  이디야커피양재AT점  양재AT점       음식   커피점/카페  서울특별시   서초구  양재2동

# %% [markdown]
# #### 전국 커피빈

# %%
df_coffeebean = df_coffee[df_coffee['상호명'].str.contains('커피빈')]
df_coffeebean.index = range(len(df_coffeebean))
print('전국 커피빈 점포 수 :', len(df_coffeebean))
df_coffeebean.head()
# Out:
# 전국 커피빈 점포 수 : 324
#    상호명             지점명 상권업종대분류명 상권업종중분류명  시도명 시군구명 행정동명
# 0  커피빈             NaN       음식   커피점/카페  강원도  동해시  묵호동
# 1  커피빈     코리아원주AK플라자점       음식   커피점/카페  강원도  원주시  단계동
# 2  커피빈    현대프리미엄아울렛김포점       음식   커피점/카페  경기도  김포시  고촌읍
# 3  커피빈  중동현대백화점U-PLEX점       음식   커피점/카페  경기도  부천시  중1동
# 4  커피빈   코리아중동위브더스테이트점       음식   커피점/카페  경기도  부천시  중2동

# %% [markdown]
# #### 서울 커피빈

# %%
df_seoul_coffeebean = df_coffeebean[df_coffeebean['시도명'] == '서울특별시']
df_seoul_coffeebean.index = range(len(df_seoul_coffeebean))
print('서울시 내 커피빈 점포 수 :', len(df_seoul_coffeebean))
df_seoul_coffeebean.head()
# Out:
# 서울시 내 커피빈 점포 수 : 191
#            상호명          지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명  행정동명
# 0          커피빈  코리아대학로대명거리점       음식   커피점/카페  서울특별시  종로구   혜화동
# 1          커피빈      코리아선릉역점       음식   커피점/카페  서울특별시  강남구  역삼1동
# 2  커피빈코리아낙성대역점     코리아낙성대역점       음식   커피점/카페  서울특별시  관악구   행운동
# 3          커피빈     코리아청담에스점       음식   커피점/카페  서울특별시  강남구   청담동
# 4          커피빈     코리아청담성당점       음식   커피점/카페  서울특별시  강남구   청담동

# %% [markdown]
# #### 전국 투썸

# %%
df_2some = df_coffee[df_coffee['상호명'].str.contains('투썸')]
df_2some.index = range(len(df_2some))
print('전국 투썸 점포 수 :', len(df_2some))
df_2some.head()
# Out:
# 전국 투썸 점포 수 : 1141
#       상호명     지점명 상권업종대분류명 상권업종중분류명  시도명 시군구명  행정동명
# 0  투썸플레이스   춘천명동점       음식   커피점/카페  강원도  춘천시   조운동
# 1  투썸플레이스   강릉포남점       음식   커피점/카페  강원도  강릉시  포남1동
# 2  투썸플레이스   춘천퇴계점       음식   커피점/카페  강원도  춘천시   퇴계동
# 3  투썸플레이스   소양강댐점       음식   커피점/카페  강원도  춘천시   신북읍
# 4  투썸플레이스  용평리조트점       음식   커피점/카페  강원도  평창군  대관령면

# %% [markdown]
# #### 서울 투썸

# %%
df_seoul_2some = df_2some[df_2some['시도명'] == '서울특별시']
df_seoul_2some.index = range(len(df_seoul_2some))
print('서울시 내 투썸 점포 수 :', len(df_seoul_2some))
df_seoul_2some.head()
# Out:
# 서울시 내 투썸 점포 수 : 286
#              상호명                지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명   행정동명
# 0         투썸플레이스              서울타워점       음식   커피점/카페  서울특별시  용산구  용산2가동
# 1  투썸플레이스서울대역중앙점            서울대역중앙점       음식   커피점/카페  서울특별시  관악구    중앙동
# 2         투썸플레이스  씨제이프레시웨이강남세브란스병원점       음식   커피점/카페  서울특별시  강남구   도곡1동
# 3         투썸플레이스           LG광화문빌딩점       음식   커피점/카페  서울특별시  종로구    사직동
# 4         투썸플레이스             가락시장역점       음식   커피점/카페  서울특별시  송파구   가락본동

# %% [markdown]
# #### 전국 빽다방

# %%
df_bbaek = df_coffee[df_coffee['상호명'].str.contains('투썸')]
df_bbaek.index = range(len(df_bbaek))
print('전국 빽다방 점포 수 :', len(df_bbaek))
df_bbaek.head()
# Out:
# 전국 빽다방 점포 수 : 1141
#       상호명     지점명 상권업종대분류명 상권업종중분류명  시도명 시군구명  행정동명
# 0  투썸플레이스   춘천명동점       음식   커피점/카페  강원도  춘천시   조운동
# 1  투썸플레이스   강릉포남점       음식   커피점/카페  강원도  강릉시  포남1동
# 2  투썸플레이스   춘천퇴계점       음식   커피점/카페  강원도  춘천시   퇴계동
# 3  투썸플레이스   소양강댐점       음식   커피점/카페  강원도  춘천시   신북읍
# 4  투썸플레이스  용평리조트점       음식   커피점/카페  강원도  평창군  대관령면

# %% [markdown]
# #### 서울 빽다방

# %%
df_seoul_bbaek = df_bbaek[df_bbaek['시도명'] == '서울특별시']
df_seoul_bbaek.index = range(len(df_seoul_bbaek))
print('서울시 내 빽다방 점포 수 :', len(df_seoul_bbaek))
df_seoul_bbaek.head()
# Out:
# 서울시 내 빽다방 점포 수 : 286
#              상호명                지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명   행정동명
# 0         투썸플레이스              서울타워점       음식   커피점/카페  서울특별시  용산구  용산2가동
# 1  투썸플레이스서울대역중앙점            서울대역중앙점       음식   커피점/카페  서울특별시  관악구    중앙동
# 2         투썸플레이스  씨제이프레시웨이강남세브란스병원점       음식   커피점/카페  서울특별시  강남구   도곡1동
# 3         투썸플레이스           LG광화문빌딩점       음식   커피점/카페  서울특별시  종로구    사직동
# 4         투썸플레이스             가락시장역점       음식   커피점/카페  서울특별시  송파구   가락본동

# %% [markdown]
# #### 전국 할리스

# %%
df_hollys = df_coffee[df_coffee['상호명'].str.contains('할리스')]
df_hollys.index = range(len(df_hollys))
print('전국 할리스 점포 수 :', len(df_hollys))
df_hollys.head()
# Out:
# 전국 할리스 점포 수 : 707
#           상호명      지점명 상권업종대분류명 상권업종중분류명  시도명 시군구명 행정동명
# 0    할리스커피전문점      NaN       음식   커피점/카페  강원도  강릉시  중앙동
# 1       할리스커피      원주점       음식   커피점/카페  강원도  원주시  단구동
# 2         할리스  에프엔비원주점       음식   커피점/카페  강원도  원주시  단구동
# 3       할리스커피      중앙점       음식   커피점/카페  강원도  원주시  중앙동
# 4  할리스커피동해묵호점    동해묵호점       음식   커피점/카페  강원도  동해시  천곡동

# %% [markdown]
# #### 서울 할리스

# %%
df_seoul_hollys = df_hollys[df_hollys['시도명'] == '서울특별시']
df_seoul_hollys.index = range(len(df_seoul_hollys))
print('서울시 내 할리스 점포 수 :', len(df_seoul_hollys))
df_seoul_hollys.head()
# Out:
# 서울시 내 할리스 점포 수 : 200
#            상호명     지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명
# 0   할리스커피남부터미널     NaN       음식   커피점/카페  서울특별시   서초구  서초1동
# 1          할리스  백석예술대점       음식   커피점/카페  서울특별시   서초구  방배3동
# 2          할리스    국기원점       음식   커피점/카페  서울특별시   강남구  역삼1동
# 3  할리스커피KBS본관점  KBS본관점       음식   커피점/카페  서울특별시  영등포구   여의동
# 4        할리스커피     선릉점       음식   커피점/카페  서울특별시   강남구  대치4동

# %% [markdown]
# #### 전국 메가커피

# %%
df_mega = df_coffee[df_coffee['상호명'].str.contains('메가커피')]
df_mega.index = range(len(df_mega))
print('전국 메가커피 점포 수 :', len(df_mega))
df_mega.head()
# Out:
# 전국 메가커피 점포 수 : 481
#           상호명     지점명 상권업종대분류명 상권업종중분류명  시도명 시군구명  행정동명
# 0     메가커피인제점     인제점       음식   커피점/카페  강원도  인제군   인제읍
# 1        메가커피     NaN       음식   커피점/카페  강원도  춘천시  후평3동
# 2        메가커피    와수리점       음식   커피점/카페  강원도  철원군    서면
# 3        메가커피  화천사창리점       음식   커피점/카페  강원도  화천군   사내면
# 4  메가커피철원문혜리점  철원문혜리점       음식   커피점/카페  강원도  철원군   갈말읍

# %% [markdown]
# #### 서울 메가커피

# %%
df_seoul_mega = df_mega[df_mega['시도명'] == '서울특별시']
df_seoul_mega.index = range(len(df_seoul_mega))
print('서울시 내 메가커피 점포 수 :', len(df_seoul_mega))
df_seoul_mega.head()
# Out:
# 서울시 내 메가커피 점포 수 : 86
#       상호명     지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명 행정동명
# 0  메가커피미아   수유시장점       음식   커피점/카페  서울특별시   강북구  미아동
# 1    메가커피     홍대점       음식   커피점/카페  서울특별시   마포구  서교동
# 2    메가커피     NaN       음식   커피점/카페  서울특별시  동대문구  용신동
# 3    메가커피     NaN       음식   커피점/카페  서울특별시   금천구  가산동
# 4    메가커피  숙대입구역점       음식   커피점/카페  서울특별시   용산구  남영동

# %% [markdown]
# ## 3. 커피전문점 별 비율 비교하기 (주요 브랜드 위주로)

# %% [markdown]
# **2020년 12월 기준 커피전문점 평판 순위**
#
#
# (source : https://www.futurekorea.co.kr/news/articleView.html?idxno=125637)

# %% [markdown]
# 1. 스타벅스
# 2. 투썸플레이스
# 3. 이디야
# 4. 메가커피
# 5. 커피빈

# %% [markdown]
# **변수**
#
# - 전체 점포 : data
# - 전체/서울 커피전문점 : df_coffee / df_seoul_starbucks
#
#
#
# - 전체/서울 스타벅스 : df_starbucks / df_seoul_starbucks
# - 전체/서울 이디야 : df_ediya / df_seoul_ediya
# - 전체/서울 커피빈 : df_coffeebean / df_seoul_coffeebean
# - 전체/서울 투썸플레이스 : df_2some / df_seoul_2some
# - 전체/서울 빽다방 : df_bbaek / df_seoul_bbaek
# - 전체/서울 할리스 : df_hollys / df_seoul_hollys
# - 전체/서울 메가커피 : df_mega / df_seoul_mega

# %% [markdown]
# ### 1) 전체 커피전문점 내 주요 커피브랜드 입점 비율

# %%
print("**** 전국 커피전문점중 주요 5대 커피브랜드 입점 비율 ****")
print("주요 5대 커피브랜드 전국 입점 비율 : %.3f%%" %((len(df_starbucks) + len(df_2some) + len(df_ediya) + len(df_mega) + len(df_coffeebean))
      /len(df_coffee)*100))
print("1. 스타벅스 : %.3f%%" % (len(df_starbucks) / len(df_coffee) * 100))
print("2. 투썸플레이스 : %.3f%%" % (len(df_2some) / len(df_coffee) * 100) )
print("3. 이디야 : %.3f%%" % (len(df_ediya) / len(df_coffee) * 100))
print("4. 메가커피 : %.3f%%" % (len(df_mega) / len(df_coffee) * 100))
print("5. 커피빈 : %.3f%%" % (len(df_coffeebean) / len(df_coffee) * 100))
# Out:
# **** 전국 커피전문점중 주요 5대 커피브랜드 입점 비율 ****
# 주요 5대 커피브랜드 전국 입점 비율 : 5.098%
# 1. 스타벅스 : 1.419%
# 2. 투썸플레이스 : 1.003%
# 3. 이디야 : 1.968%
# 4. 메가커피 : 0.423%
# 5. 커피빈 : 0.285%

# %% [markdown]
# ### 2) 서울 커피전문점 내 주요 커피브랜드 입점 비율

# %%
print("스타벅스 : %.3f%%" % (len(df_seoul_starbucks) / len(df_seoul_coffee) * 100))
print("이디야 : %.3f%%" % (len(df_seoul_ediya) / len(df_seoul_coffee) * 100) )
print("커피빈 : %.3f%%" % (len(df_seoul_coffeebean) / len(df_seoul_coffee) * 100))
print("투썸플레이스 : %.3f%%" % (len(df_seoul_2some) / len(df_seoul_coffee) * 100))
print("빽다방 : %.3f%%" % (len(df_seoul_bbaek) / len(df_seoul_coffee) * 100))
print("할리스 : %.3f%%" %(len(df_seoul_hollys) / len(df_seoul_coffee) * 100) )
print("메가커피 : %.3f%%" % (len(df_seoul_mega) / len(df_seoul_coffee) * 100))
# Out:
# 스타벅스 : 2.289%
# 이디야 : 2.131%
# 커피빈 : 0.859%
# 투썸플레이스 : 1.286%
# 빽다방 : 1.286%
# 할리스 : 0.899%
# 메가커피 : 0.387%

# %% [markdown]
# ### 3) 각 커피브랜드별 서울 입점 비율

# %%
print("**** 주요 5대 커피브랜드별 서울 입점 비율 ****")
print("1. 스타벅스 : %.3f%%" % (len(df_seoul_starbucks) / len(df_starbucks) * 100))
print("2. 투썸플레이스 : %.3f%%" % (len(df_seoul_2some) / len(df_2some) * 100) )
print("3. 이디야 : %.3f%%" %  (len(df_seoul_ediya) / len(df_ediya) * 100))
print("4. 메가커피 : %.3f%%" %  (len(df_seoul_mega) / len(df_mega) * 100))
print("5. 커피빈 : %.3f%%" % (len(df_seoul_coffeebean) / len(df_coffeebean) * 100) )
# Out:
# **** 주요 5대 커피브랜드별 서울 입점 비율 ****
# 1. 스타벅스 : 31.556%
# 2. 투썸플레이스 : 25.066%
# 3. 이디야 : 21.180%
# 4. 메가커피 : 17.879%
# 5. 커피빈 : 58.951%

# %%
# 각 구별로 스타벅스가 얼마나 있는지 확인합니다.
starbucks_gu = df_seoul_starbucks.groupby('시군구명')['상호명'].count().to_frame().sort_values(by='상호명', ascending=False)
starbucks_gu = starbucks_gu.reset_index()
starbucks_gu = starbucks_gu.set_index('시군구명')
starbucks_gu
# Out:
#       상호명
# 시군구명
# 강남구    87
# 중구     48
# 서초구    44
# 송파구    33
# 종로구    31
# 마포구    28
# 영등포구   26
# 용산구    21
# 서대문구   21
# 강서구    19
# 광진구    17
# 강동구    15
# 성북구    15
# 금천구    12
# 양천구    12
# 노원구    11
# 동작구    11
# 관악구    11
# 구로구     9
# 은평구     9
# 성동구     8
# 동대문구    7
# 중랑구     7
# 강북구     5
# 도봉구     2

# %%
# 시각화를 위한 라이브러리를 불러옵니다.
import seaborn as sns
import matplotlib.pyplot as plt
import platform

from matplotlib import font_manager, rc
# %matplotlib inline

# %%
#### Windows10 사용자는 해당 코드가 필요없습니다!

# macos에서 사용가능한 한글 글꼴 확인 코드
[f.name for f in font_manager.fontManager.ttflist if 'Neo' in f.name]

# %%
## 운영체제별 글꼴 세팅

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    font_name = 'Apple SD Gothic Neo'
    rc('font', family='Apple SD Gothic Neo')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    font_name = font_manager.FontProperties(fname="/usr/share/fonts/nanumfont/NanumGothic.ttf")
    rc('font', family="NanumGothic")

# %%
# 주요 5대 커피브랜드 서울 입점 비율을 시각화합니다.

print("**** 주요 5대 커피브랜드별 서울 입점 비율 ****")

starbucks_rate = (len(df_seoul_starbucks) / len(df_starbucks) * 100)
some_rate = (len(df_seoul_2some) / len(df_2some) * 100) 
ediya_rate = (len(df_seoul_ediya) / len(df_ediya) * 100)
mega_rate = (len(df_seoul_mega) / len(df_mega) * 100)
coffeebean_rate = (len(df_seoul_coffeebean) / len(df_coffeebean) * 100) 

x = [ '스타벅스', '투썸', '이디야', '메가', '커피빈']
y = [starbucks_rate, some_rate, ediya_rate, mega_rate, coffeebean_rate]

plt.figure(figsize=(12,12))
plt.title('주요 5대 커피브랜드 서울 입점 비율', fontdict={'fontsize' : 20})
sns.barplot(x=x, y=y)
# Out:
# **** 주요 5대 커피브랜드별 서울 입점 비율 ****
# <AxesSubplot:title={'center':'주요 5대 커피브랜드 서울 입점 비율'}>

# %% [markdown]
# ### (Challenge) More Prettier!

# %%
# 위의 barplot을 seaborn을 이용하여 더욱 멋지게 시각화해보세요!

print("**** 서울 커피전문점 내 주요 커피브랜드 입점 비율 ****")
starbucks_rate = len(df_seoul_starbucks) / len(df_seoul_coffee) * 100
some_rate = len(df_seoul_2some) / len(df_seoul_coffee) * 100
ediya_rate = len(df_seoul_ediya) / len(df_seoul_coffee) * 100
mega_rate = len(df_seoul_mega) / len(df_seoul_coffee) * 100
coffeebean_rate = len(df_seoul_coffeebean) / len(df_seoul_coffee) * 100

x = [ '스타벅스', '투썸', '이디야', '메가', '커피빈']
y = [starbucks_rate, some_rate, ediya_rate, mega_rate, coffeebean_rate]

plt.figure(figsize=(12,12))
plt.title('서울 커피전문점 내 주요 커피브랜드 입점 비율', fontdict={'fontsize' : 20})
sns.barplot(x=x, y=y)
# Out:
# **** 서울 커피전문점 내 주요 커피브랜드 입점 비율 ****
# <AxesSubplot:title={'center':'서울 커피전문점 내 주요 커피브랜드 입점 비율'}>
