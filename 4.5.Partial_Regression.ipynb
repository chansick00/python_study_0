# %% [markdown]
# ## 부분회귀 플롯

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import sklearn as sk
import statsmodels.api as sm
import seaborn as sns
import matplotlib as mpl

# %%
from sklearn.datasets import load_boston

boston = load_boston()

dfX0 = pd.DataFrame(boston.data, columns=boston.feature_names)
dfX = sm.add_constant(dfX0)
dfy = pd.DataFrame(boston.target, columns = ['MEDV'])
df = pd.concat([dfX, dfy], axis=1)

model_boston = sm.OLS(dfy, dfX)
result_boston = model_boston.fit()

# %%
sns.regplot(x='AGE', y='MEDV', data=df)
plt.show()

# %%
others = list(set(df.columns).difference(set(['MEDV', 'AGE'])))  #df의 columns에서 'MEDV'와 'AGE'뺴기
p, reids = sm.graphics.plot_partregress(
    'MEDV', 'AGE', others, data=df, obs_labels=False, ret_coords=True)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(8, 20))
sm.graphics.plot_partregress_grid(result_boston, fig=fig)
fig.suptitle("")
plt.show()
# Out:
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1

# %%
sm.graphics.plot_ccpr(result_boston, 'AGE')
plt.show()

# %%
fig = plt.figure(figsize=(8, 15))
sm.graphics.plot_ccpr_grid(result_boston, fig=fig)
fig.suptitle('')
plt.show()

# %%
fig = sm.graphics.plot_regress_exog(result_boston, 'AGE')
plt.show()
# Out:
# eval_env: 1
